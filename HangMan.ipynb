# %% [markdown]
# <a href="https://colab.research.google.com/github/JonMyles494/My-First-Repo/blob/main/HangMan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#can you code this at a beginners level

# Hangman game
#

# -----------------------------------
# Helper code
# You don't need to understand this helper code,
# but you will have to know how to use the functions
# (so be sure to read the docstrings!)

import random
import string

WORDLIST_FILENAME = "words.txt"

def loadWords():
    """
    Returns a list of valid words. Words are strings of lowercase letters.

    Depending on the size of the word list, this function may
    take a while to finish.
    """
    print("Loading word list from file...")
    # inFile: file
    #inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    #line = inFile.readline()
    # wordlist: list of strings
    wordlist =  ['lime', 'lime']
    print("  ", len(wordlist), "words loaded.")
    return wordlist

def chooseWord(wordlist):
    """
    wordlist (list): list of words (strings)

    Returns a word from wordlist at random
    """
    return random.choice(wordlist)

# end of helper code
# -----------------------------------

# Load the list of words into the variable wordlist
# so that it can be accessed from anywhere in the program
wordlist = loadWords()

def isWordGuessed(secretWord, lettersGuessed):
    '''
    secretWord: string, the word the user is guessing
    lettersGuessed: list, what letters have been guessed so far
    returns: boolean, True if all the letters of secretWord are in lettersGuessed;
      False otherwise
    '''
    # FILL IN YOUR CODE HERE...
    for letter in secretWord:
      if letter not in lettersGuessed:
        return False
    return True



def getGuessedWord(secretWord, lettersGuessed):
    '''
    secretWord: string, the word the user is guessing
    lettersGuessed: list, what letters have been guessed so far
    returns: string, comprised of letters and underscores that represents
      what letters in secretWord have been guessed so far.
    '''
    # FILL IN YOUR CODE HERE...
    # Establish variables
    guessedWord = ''

    # Cycle thru each letter in the word to check if the letter has been guessed
    for letter in secretWord:
      if letter in lettersGuessed:
        guessedWord += letter
      else:
        guessedWord += "_ "
    return guessedWord



def getAvailableLetters(lettersGuessed):
    '''
    lettersGuessed: list, what letters have been guessed so far
    returns: string, comprised of letters that represents what letters have not
      yet been guessed.
    '''
    # FILL IN YOUR CODE HERE...
    # Establish variables
    availableLetters = ''

    for letter in string.ascii_lowercase:
      if letter not in lettersGuessed:
        availableLetters += letter
    return availableLetters


def hangman(secretWord):
    '''
    secretWord: string, the secret word to guess.

    Starts up an interactive game of Hangman.

    * At the start of the game, let the user know how many
      letters the secretWord contains.

    * Ask the user to supply one guess (i.e. letter) per round.

    * The user should receive feedback immediately after each guess
      about whether their guess appears in the computers word.

    * After each round, you should also display to the user the
      partially guessed word so far, as well as letters that the
      user has not yet guessed.

    Follows the other limitations detailed in the problem write-up.
    '''
    # FILL IN YOUR CODE HERE...
    # Establish variables
    lettersGuessed = []
    mistakesMade = 0
    maxGuesses = 8

    # While the game is not over
    print("LETS PLAY HANGMAN!")
    while mistakesMade < maxGuesses and not isWordGuessed(secretWord, lettersGuessed):
      print(f"You have {maxGuesses - mistakesMade} guesses left.")
      print(f"Availabe letters:" , getAvailableLetters(lettersGuessed))

      # Prompt user for letter
      guess = input("Please enter a letter: ").lower()

      # Check user input to see if it has been used prior
      if guess in lettersGuessed:
        print(f"Ooops! It appears you have already entered this letter, please enter a different choice: ",getGuessedWord(secretWord, lettersGuessed))
        print("  ") # space
       # Check if guess is corect
      elif guess in secretWord:
        lettersGuessed.append(guess)
        print(f"Good job! That letter '{guess}' is in the word. ",getGuessedWord(secretWord, lettersGuessed))
        print("  ") # space
       # Guess is incorrect
      else:
        lettersGuessed.append(guess)
        mistakesMade +=1
        print(f"I'm sorry that letter is not in this word: ", getGuessedWord(secretWord, lettersGuessed))

        print('----------------------')
        print("  ") # space

     # Check to see if player has won or lost
    if isWordGuessed(secretWord, lettersGuessed):
      print("Congradulations, you won!")
    else:
      print(f"Sorry, you ran out of guessed. The word was '{secretWord}'.")








# When you've completed your hangman function, uncomment these two lines
# and run this file to test! (hint: you might want to pick your own
# secretWord while you're testing)

secretWord = chooseWord(wordlist).lower()
hangman(secretWord)
# Out:
# Loading word list from file...
#    2 words loaded.
# LETS PLAY HANGMAN!
# You have 8 guesses left.
# Availabe letters: abcdefghijklmnopqrstuvwxyz
# Please enter a letter: e
# Good job! That letter 'e' is in the word.  _ _ _ e
#
# You have 8 guesses left.
# Availabe letters: abcdfghijklmnopqrstuvwxyz
# Please enter a letter: f
# I'm sorry that letter is not in this word:  _ _ _ e
# ----------------------
#
# You have 7 guesses left.
# Availabe letters: abcdghijklmnopqrstuvwxyz
# Please enter a letter: e
# Ooops! It appears you have already entered this letter, please enter a different choice:  _ _ _ e
#
# You have 7 guesses left.
# Availabe letters: abcdghijklmnopqrstuvwxyz
# Please enter a letter: g
# I'm sorry that letter is not in this word:  _ _ _ e
# ----------------------
#
# You have 6 guesses left.
# Availabe letters: abcdhijklmnopqrstuvwxyz
# Please enter a letter: l
# Good job! That letter 'l' is in the word.  l_ _ e
#
# You have 6 guesses left.
# ...
